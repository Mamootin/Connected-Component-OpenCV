# %% [raw]
# **#%% md
# Connected Component**
#
# Load neccessery libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# import images in default and gray scale mode

# %%
img = cv2.imread("HandWrite.jpg")
img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

gray = cv2.imread("HandWrite.jpg", cv2.IMREAD_GRAYSCALE)
gray = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)

#plt.imshow(gray, cmap="gray")
plt.imshow(img)

# %%
print(repr(gray))
# Out:
# array([[154, 152, 148, ..., 114, 107, 101],
#        [157, 143, 151, ..., 107, 106, 106],
#        [162, 147, 148, ..., 100, 113, 108],
#        ...,
#        [142, 127, 123, ..., 103, 102, 105],
#        [136, 130, 127, ..., 102, 102, 101],
#        [130, 129, 132, ..., 101, 103,  98]], dtype=uint8)

# %% [markdown]
# Convert image data to binary

# %%
gray.shape
gray[gray<127.5]=0
gray[gray>127.5]=255
plt.imshow(gray, cmap="gray")
